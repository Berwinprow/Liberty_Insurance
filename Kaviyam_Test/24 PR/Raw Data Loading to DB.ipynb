# %%
import pandas as pd
from sqlalchemy import create_engine

# Database connection setup
db_config = {
    'host': 'localhost',
    'database': 'postgres',
    'user': 'postgres',
    'password': 'kaviyam123',
    'port': '5432'
}
connection_string = f"postgresql://{db_config['user']}:{db_config['password']}@{db_config['host']}:{db_config['port']}/{db_config['database']}"
engine = create_engine(connection_string)

# Step 1: Load the Excel or CSV file
file_path = "Pvt Car Jan to  Nov 24.xlsx"  
if file_path.endswith('.csv'):
    data = pd.read_csv(file_path)  # Load CSV
elif file_path.endswith('.xlsx'):
    data = pd.read_excel(file_path)  # Load Excel
else:
    raise ValueError("Unsupported file format. Please provide a .csv or .xlsx file.")

# Step 2: Specify the target table name in the database
table_name = "2024_base_data" 

data.to_sql(
    name=table_name,
    con=engine,
    if_exists='replace',
    index=False  
)

# Step 4: Confirmation
print(f"Data successfully loaded into the table '{table_name}' in the database '{db_config['database']}'.")
# Out:
# Data successfully loaded into the table '2024_base_data' in the database 'postgres'.

# %%
import pandas as pd
from sqlalchemy import create_engine

# Database connection setup
db_config = {
    'host': 'localhost',
    'database': 'postgres',
    'user': 'postgres',
    'password': 'kaviyam123',
    'port': '5432'
}
connection_string = f"postgresql://{db_config['user']}:{db_config['password']}@{db_config['host']}:{db_config['port']}/{db_config['database']}"
engine = create_engine(connection_string)

# Step 1: Load the Excel or CSV file
file_path = "2024 PR.xlsx"  
if file_path.endswith('.csv'):
    data = pd.read_csv(file_path)  # Load CSV
elif file_path.endswith('.xlsx'):
    data = pd.read_excel(file_path)  # Load Excel
else:
    raise ValueError("Unsupported file format. Please provide a .csv or .xlsx file.")

# Step 2: Specify the target table name in the database
table_name = "2024_PR_data" 

data.to_sql(
    name=table_name,
    con=engine,
    if_exists='replace',
    index=False  
)

# Step 4: Confirmation
print(f"Data successfully loaded into the table '{table_name}' in the database '{db_config['database']}'.")
# Out:
# Data successfully loaded into the table '2024_PR_data' in the database 'postgres'.

# %%
import pandas as pd
from sqlalchemy import create_engine

# Database connection setup
db_config = {
    'host': 'localhost',
    'database': 'postgres',
    'user': 'postgres',
    'password': 'kaviyam123',
    'port': '5432'
}
connection_string = f"postgresql://{db_config['user']}:{db_config['password']}@{db_config['host']}:{db_config['port']}/{db_config['database']}"
engine = create_engine(connection_string)

# Step 1: Load the Excel or CSV file
file_path = "Indian_States_Direction_Final.csv"  
if file_path.endswith('.csv'):
    data = pd.read_csv(file_path)  # Load CSV
elif file_path.endswith('.xlsx'):
    data = pd.read_excel(file_path)  # Load Excel
else:
    raise ValueError("Unsupported file format. Please provide a .csv or .xlsx file.")

# Step 2: Specify the target table name in the database
table_name = "state_zone_dim" 

data.to_sql(
    name=table_name,
    con=engine,
    if_exists='replace',
    index=False  
)

# Step 4: Confirmation
print(f"Data successfully loaded into the table '{table_name}' in the database '{db_config['database']}'.")
# Out:
# Data successfully loaded into the table 'state_zone_dim' in the database 'postgres'.
