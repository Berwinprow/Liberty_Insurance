# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier, export_text, plot_tree
from sklearn.impute import SimpleImputer
import numpy as np

df = pd.read_excel('D:\Liberty (Base data work)\Actual data (South).xlsx')
# Out:
# <>:9: SyntaxWarning: invalid escape sequence '\L'
# <>:9: SyntaxWarning: invalid escape sequence '\L'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7696\1321730406.py:9: SyntaxWarning: invalid escape sequence '\L'
#   df = pd.read_excel('D:\Liberty (Base data work)\Actual data (South).xlsx')

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.impute import SimpleImputer
import pandas as pd

# Filter data
df_filtered = df[~df['Policy Status'].str.contains('Open', case=False, na=False)]
df_filtered = df_filtered[df_filtered['Policy Status'].str.contains('Renewed|Not Renewed', case=False, na=False)]

# Create binary status
df_filtered['Status_Binary'] = df_filtered['Churn Label'].apply(lambda x: 1 if x == 'Yes' else 0)

# Selected columns
selected_columns = ['variant', 'RTO Location ', 'Product name  2', 'biztype', 'age', 'Number of Vehicles', 'Number of Policies',
                    'Total Premium Payable (Overall)', 'Total OD Premium (Overall)',
                    'Total TP Premium (Overall)', 'Total Add on Premium (Overall)', 'Average Discount (Overall)',
                    'Average NCB % Previous Year (Overall)', 'Total GST (Overall)', 'Number of Claims',
                    'Number of Declines', 'New Customer', 'Customer Tenure ', 'Status_Binary']

df_selected = df_filtered[selected_columns]

# Label encoding for high-cardinality categorical features
label_enc_features = ['variant', 'RTO Location ',  'age']
for col in label_enc_features:
    le = LabelEncoder()
    df_selected[col] = le.fit_transform(df_selected[col].astype(str))

# One-hot encode remaining low-cardinality features
df_selected = pd.get_dummies(df_selected, drop_first=True)

# Impute missing values
imputer = SimpleImputer(strategy='constant', fill_value=0)
X = imputer.fit_transform(df_selected.drop(columns=['Status_Binary']))
y = df_selected['Status_Binary']

print(f"Shape of X: {X.shape}")
print(f"Shape of y: {y.shape}")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7696\3269962299.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected[col] = le.fit_transform(df_selected[col].astype(str))
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7696\3269962299.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected[col] = le.fit_transform(df_selected[col].astype(str))
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7696\3269962299.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected[col] = le.fit_transform(df_selected[col].astype(str))
# Shape of X: (294293, 33)
# Shape of y: (294293,)

# %%
# Evaluate Decision tree model
dt_model_moderate = DecisionTreeClassifier(
    max_depth=7,                
    min_samples_split=20,       
    min_samples_leaf=10,        
    random_state=42
)
dt_model_moderate.fit(X, y)

# Export tree rules as text
tree_rules_moderate = export_text(dt_model_moderate, feature_names=df_selected.drop(columns=['Status_Binary']).columns)
print("\nModerate Decision Tree Rules:")
print(tree_rules_moderate)

# Plot the decision tree
plt.figure(figsize=(40, 20))  
plot_tree(dt_model_moderate, 
          feature_names=df_selected.drop(columns=['Status_Binary']).columns, 
          class_names=['Renewed/Delayed Renewed', 'Not Renewed'], 
          filled=True)

plt.title('Moderate Decision Tree for Policy Non-Renewal Reasons')

plt.savefig("decision_tree_large South.png", dpi=300)  
plt.show()

with open("decision_tree_rules_test South.txt", "w") as file:
    file.write(tree_rules_moderate)
# Out:
# Moderate Decision Tree Rules:
# |--- Customer Tenure  <= 1.50
# |   |--- Average Discount (Overall) <= 77.07
# |   |   |--- biztype_Roll Over <= 0.50
# |   |   |   |--- Average Discount (Overall) <= 72.03
# |   |   |   |   |--- Average Discount (Overall) <= 63.45
# |   |   |   |   |   |--- variant <= 2068.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- variant >  2068.50
# |   |   |   |   |   |   |--- age <= 351.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- age >  351.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- Average Discount (Overall) >  63.45
# |   |   |   |   |   |--- variant <= 5964.00
# |   |   |   |   |   |   |--- biztype_Renewal Business <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- biztype_Renewal Business >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- variant >  5964.00
# |   |   |   |   |   |   |--- variant <= 14630.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- variant >  14630.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- Average Discount (Overall) >  72.03
# |   |   |   |   |--- age <= 1176.00
# |   |   |   |   |   |--- age <= 775.50
# |   |   |   |   |   |   |--- Total Add on Premium (Overall) <= 4469.07
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Total Add on Premium (Overall) >  4469.07
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- age >  775.50
# |   |   |   |   |   |   |--- variant <= 16552.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- variant >  16552.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- age >  1176.00
# |   |   |   |   |   |--- biztype_Roll Over, New Business <= 0.50
# |   |   |   |   |   |   |--- variant <= 10237.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- variant >  10237.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- biztype_Roll Over, New Business >  0.50
# |   |   |   |   |   |   |--- variant <= 9784.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- variant >  9784.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |--- biztype_Roll Over >  0.50
# |   |   |   |--- Number of Declines <= 0.50
# |   |   |   |   |--- Total OD Premium (Overall) <= 100.00
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- Total OD Premium (Overall) >  100.00
# |   |   |   |   |   |--- age <= 11299.00
# |   |   |   |   |   |   |--- Average Discount (Overall) <= 63.32
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Average Discount (Overall) >  63.32
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- age >  11299.00
# |   |   |   |   |   |   |--- Average NCB % Previous Year (Overall) <= 2.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Average NCB % Previous Year (Overall) >  2.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- Number of Declines >  0.50
# |   |   |   |   |--- Number of Vehicles <= 1.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- Number of Vehicles >  1.50
# |   |   |   |   |   |--- Total TP Premium (Overall) <= 8855.50
# |   |   |   |   |   |   |--- age <= 7153.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- age >  7153.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Total TP Premium (Overall) >  8855.50
# |   |   |   |   |   |   |--- class: 1
# |   |--- Average Discount (Overall) >  77.07
# |   |   |--- biztype_Renewal Business <= 0.50
# |   |   |   |--- age <= 7262.50
# |   |   |   |   |--- age <= 848.00
# |   |   |   |   |   |--- Total Add on Premium (Overall) <= 9975.85
# |   |   |   |   |   |   |--- RTO Location  <= 929.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- RTO Location  >  929.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Total Add on Premium (Overall) >  9975.85
# |   |   |   |   |   |   |--- Total Add on Premium (Overall) <= 10377.12
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Total Add on Premium (Overall) >  10377.12
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- age >  848.00
# |   |   |   |   |   |--- age <= 7121.50
# |   |   |   |   |   |   |--- Total Add on Premium (Overall) <= 5010.59
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Total Add on Premium (Overall) >  5010.59
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- age >  7121.50
# |   |   |   |   |   |   |--- variant <= 16176.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- variant >  16176.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- age >  7262.50
# |   |   |   |   |--- Average NCB % Previous Year (Overall) <= 3.33
# |   |   |   |   |   |--- Total TP Premium (Overall) <= 4078.50
# |   |   |   |   |   |   |--- Total GST (Overall) <= 833.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Total GST (Overall) >  833.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Total TP Premium (Overall) >  4078.50
# |   |   |   |   |   |   |--- Number of Claims <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Number of Claims >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- Average NCB % Previous Year (Overall) >  3.33
# |   |   |   |   |   |--- variant <= 8774.50
# |   |   |   |   |   |   |--- variant <= 4913.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- variant >  4913.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- variant >  8774.50
# |   |   |   |   |   |   |--- variant <= 17708.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- variant >  17708.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |--- biztype_Renewal Business >  0.50
# |   |   |   |--- RTO Location  <= 1319.50
# |   |   |   |   |--- Total OD Premium (Overall) <= 840.00
# |   |   |   |   |   |--- Total OD Premium (Overall) <= 775.00
# |   |   |   |   |   |   |--- Average Discount (Overall) <= 78.75
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Average Discount (Overall) >  78.75
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Total OD Premium (Overall) >  775.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- Total OD Premium (Overall) >  840.00
# |   |   |   |   |   |--- Average NCB % Previous Year (Overall) <= 10.00
# |   |   |   |   |   |   |--- variant <= 8817.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- variant >  8817.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Average NCB % Previous Year (Overall) >  10.00
# |   |   |   |   |   |   |--- variant <= 9851.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- variant >  9851.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- RTO Location  >  1319.50
# |   |   |   |   |--- variant <= 8250.00
# |   |   |   |   |   |--- variant <= 4294.00
# |   |   |   |   |   |   |--- variant <= 3867.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- variant >  3867.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- variant >  4294.00
# |   |   |   |   |   |   |--- Product name  2_SOD <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Product name  2_SOD >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- variant >  8250.00
# |   |   |   |   |   |--- variant <= 16159.50
# |   |   |   |   |   |   |--- Total GST (Overall) <= 792.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Total GST (Overall) >  792.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- variant >  16159.50
# |   |   |   |   |   |   |--- Total Add on Premium (Overall) <= 6154.66
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Total Add on Premium (Overall) >  6154.66
# |   |   |   |   |   |   |   |--- class: 1
# |--- Customer Tenure  >  1.50
# |   |--- New Customer_Yes <= 0.50
# |   |   |--- Number of Policies <= 1.50
# |   |   |   |--- biztype_Renewal Business <= 0.50
# |   |   |   |   |--- Average Discount (Overall) <= 76.81
# |   |   |   |   |   |--- age <= 10753.50
# |   |   |   |   |   |   |--- variant <= 16644.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- variant >  16644.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- age >  10753.50
# |   |   |   |   |   |   |--- Average Discount (Overall) <= 52.75
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Average Discount (Overall) >  52.75
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- Average Discount (Overall) >  76.81
# |   |   |   |   |   |--- Total Premium Payable (Overall) <= 14141.00
# |   |   |   |   |   |   |--- age <= 2420.00
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- age >  2420.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Total Premium Payable (Overall) >  14141.00
# |   |   |   |   |   |   |--- Total Premium Payable (Overall) <= 17021.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Total Premium Payable (Overall) >  17021.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- biztype_Renewal Business >  0.50
# |   |   |   |   |--- Customer Tenure  <= 2.50
# |   |   |   |   |   |--- Total Premium Payable (Overall) <= 9772.50
# |   |   |   |   |   |   |--- Total Add on Premium (Overall) <= 5511.53
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Total Add on Premium (Overall) >  5511.53
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Total Premium Payable (Overall) >  9772.50
# |   |   |   |   |   |   |--- Total Add on Premium (Overall) <= 10367.62
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Total Add on Premium (Overall) >  10367.62
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- Customer Tenure  >  2.50
# |   |   |   |   |   |--- Total OD Premium (Overall) <= 6914.50
# |   |   |   |   |   |   |--- Total Add on Premium (Overall) <= 373.15
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Total Add on Premium (Overall) >  373.15
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- Total OD Premium (Overall) >  6914.50
# |   |   |   |   |   |   |--- Total Add on Premium (Overall) <= 9531.66
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Total Add on Premium (Overall) >  9531.66
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |--- Number of Policies >  1.50
# |   |   |   |--- Average Discount (Overall) <= 73.75
# |   |   |   |   |--- Number of Policies <= 2.50
# |   |   |   |   |   |--- Number of Declines <= 0.50
# |   |   |   |   |   |   |--- Product name  2_SOD, Package <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Product name  2_SOD, Package >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Number of Declines >  0.50
# |   |   |   |   |   |   |--- biztype_Renewal Business <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- biztype_Renewal Business >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- Number of Policies >  2.50
# |   |   |   |   |   |--- Number of Policies <= 3.50
# |   |   |   |   |   |   |--- Total OD Premium (Overall) <= 23874.00
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Total OD Premium (Overall) >  23874.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Number of Policies >  3.50
# |   |   |   |   |   |   |--- Total GST (Overall) <= 8423.08
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Total GST (Overall) >  8423.08
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- Average Discount (Overall) >  73.75
# |   |   |   |   |--- Number of Declines <= 0.50
# |   |   |   |   |   |--- Number of Policies <= 2.50
# |   |   |   |   |   |   |--- Average Discount (Overall) <= 80.04
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Average Discount (Overall) >  80.04
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- Number of Policies >  2.50
# |   |   |   |   |   |   |--- Total GST (Overall) <= 4651.32
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Total GST (Overall) >  4651.32
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- Number of Declines >  0.50
# |   |   |   |   |   |--- Number of Policies <= 3.50
# |   |   |   |   |   |   |--- biztype_Renewal Business <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- biztype_Renewal Business >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Number of Policies >  3.50
# |   |   |   |   |   |   |--- class: 0
# |   |--- New Customer_Yes >  0.50
# |   |   |--- Customer Tenure  <= 2.50
# |   |   |   |--- Number of Vehicles <= 1.50
# |   |   |   |   |--- Number of Declines <= 0.50
# |   |   |   |   |   |--- Average Discount (Overall) <= 63.08
# |   |   |   |   |   |   |--- age <= 1160.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- age >  1160.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- Average Discount (Overall) >  63.08
# |   |   |   |   |   |   |--- RTO Location  <= 487.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- RTO Location  >  487.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- Number of Declines >  0.50
# |   |   |   |   |   |--- Average Discount (Overall) <= 57.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Average Discount (Overall) >  57.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- Number of Vehicles >  1.50
# |   |   |   |   |--- age <= 1120.00
# |   |   |   |   |   |--- Average Discount (Overall) <= 59.75
# |   |   |   |   |   |   |--- Total Add on Premium (Overall) <= 16012.29
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Total Add on Premium (Overall) >  16012.29
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- Average Discount (Overall) >  59.75
# |   |   |   |   |   |   |--- biztype_New Business, Renewal Business <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- biztype_New Business, Renewal Business >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- age >  1120.00
# |   |   |   |   |   |--- Number of Declines <= 0.50
# |   |   |   |   |   |   |--- Average Discount (Overall) <= 68.42
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Average Discount (Overall) >  68.42
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- Number of Declines >  0.50
# |   |   |   |   |   |   |--- Total TP Premium (Overall) <= 14780.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Total TP Premium (Overall) >  14780.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |--- Customer Tenure  >  2.50
# |   |   |   |--- Average NCB % Previous Year (Overall) <= 1.67
# |   |   |   |   |--- age <= 8316.00
# |   |   |   |   |   |--- Total OD Premium (Overall) <= 21875.00
# |   |   |   |   |   |   |--- RTO Location  <= 1164.00
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- RTO Location  >  1164.00
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- Total OD Premium (Overall) >  21875.00
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- age >  8316.00
# |   |   |   |   |   |--- age <= 8397.50
# |   |   |   |   |   |   |--- Customer Tenure  <= 3.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Customer Tenure  >  3.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- age >  8397.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- Average NCB % Previous Year (Overall) >  1.67
# |   |   |   |   |--- variant <= 18199.00
# |   |   |   |   |   |--- Total Premium Payable (Overall) <= 4966.50
# |   |   |   |   |   |   |--- RTO Location  <= 419.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- RTO Location  >  419.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- Total Premium Payable (Overall) >  4966.50
# |   |   |   |   |   |   |--- Average NCB % Previous Year (Overall) <= 11.83
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Average NCB % Previous Year (Overall) >  11.83
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- variant >  18199.00
# |   |   |   |   |   |--- class: 0

# %%
import xgboost as xgb
from sklearn.metrics import accuracy_score, log_loss, roc_auc_score, classification_report, confusion_matrix, roc_curve
import matplotlib.pyplot as plt

model = xgb.XGBClassifier(
    max_depth=6,
    learning_rate=0.1,
    n_estimators=100,
    random_state=42
)

model.fit(X, y)

# Evaluate the Feature Importance
feature_importances = pd.Series(model.feature_importances_, index=df_selected.drop(columns=['Status_Binary']).columns)

print("Feature Importance (all features):")
print(feature_importances)

# Plot the Feature importance graph
plt.figure(figsize=(20, 12))
sns.barplot(x=feature_importances.sort_values(ascending=False), y=feature_importances.sort_values(ascending=False).index, palette="coolwarm")
plt.title('Feature Importance')
plt.xlabel('Importance')
plt.ylabel('Features')
plt.show()

feature_importances_df = pd.DataFrame({'Feature': feature_importances.index, 'Importance': feature_importances.values})
feature_importances_df.to_csv('feature_importances south.csv', index=False)
# Out:
# Feature Importance (all features):
# variant                                              0.005271
# RTO Location                                         0.002542
# age                                                  0.007977
# Number of Vehicles                                   0.006571
# Number of Policies                                   0.163356
# Total Premium Payable (Overall)                      0.005307
# Total OD Premium (Overall)                           0.002739
# Total TP Premium (Overall)                           0.001877
# Total Add on Premium (Overall)                       0.004182
# Average Discount (Overall)                           0.011731
# Average NCB % Previous Year (Overall)                0.010389
# Total GST (Overall)                                  0.002756
# Number of Claims                                     0.004096
# Number of Declines                                   0.014591
# Customer Tenure                                      0.281522
# Product name  2_Package, SOD                         0.001096
# Product name  2_SOD                                  0.011971
# Product name  2_SOD, Package                         0.005273
# biztype_New Business, Renewal Business               0.001258
# biztype_New Business, Renewal Business, Roll Over    0.000000
# biztype_New Business, Roll Over                      0.003067
# biztype_New Business, Roll Over, Renewal Business    0.000000
# biztype_Renewal Business                             0.015180
# biztype_Renewal Business, New Business               0.000000
# biztype_Renewal Business, New Business, Roll Over    0.000660
# biztype_Renewal Business, Roll Over                  0.001583
# biztype_Renewal Business, Roll Over, New Business    0.000000
# biztype_Roll Over                                    0.021090
# biztype_Roll Over, New Business                      0.001738
# biztype_Roll Over, New Business, Renewal Business    0.000000
# biztype_Roll Over, Renewal Business                  0.001425
# biztype_Roll Over, Renewal Business, New Business    0.000000
# New Customer_Yes                                     0.410749
# dtype: float32
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7696\1498533728.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=feature_importances.sort_values(ascending=False), y=feature_importances.sort_values(ascending=False).index, palette="coolwarm")
