# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier, export_text, plot_tree
from sklearn.impute import SimpleImputer
import numpy as np

df = pd.read_excel('D:\Liberty (Base data work)\Actual data (East).xlsx')
# Out:
# <>:9: SyntaxWarning: invalid escape sequence '\L'
# <>:9: SyntaxWarning: invalid escape sequence '\L'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15492\315307129.py:9: SyntaxWarning: invalid escape sequence '\L'
#   df = pd.read_excel('D:\Liberty (Base data work)\Actual data (East).xlsx')

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.impute import SimpleImputer
import pandas as pd

# Filter data
df_filtered = df[~df['Policy Status'].str.contains('Open', case=False, na=False)]
df_filtered = df_filtered[df_filtered['Policy Status'].str.contains('Renewed|Not Renewed', case=False, na=False)]

# Create binary status
df_filtered['Status_Binary'] = df_filtered['Churn Label'].apply(lambda x: 1 if x == 'Yes' else 0)

# Selected columns
selected_columns = ['variant', 'RTO Location ', 'Product name  2', 'biztype', 'age', 'Number of Vehicles', 'Number of Policies',
                    'Total Premium Payable (Overall)', 'Total OD Premium (Overall)',
                    'Total TP Premium (Overall)', 'Total Add on Premium (Overall)', 'Average Discount (Overall)',
                    'Average NCB % Previous Year (Overall)', 'Total GST (Overall)', 'Number of Claims',
                    'Number of Declines', 'New Customer', 'Customer Tenure ', 'Status_Binary']

df_selected = df_filtered[selected_columns]

# Label encoding for high-cardinality categorical features
label_enc_features = ['variant', 'RTO Location ',  'age']
for col in label_enc_features:
    le = LabelEncoder()
    df_selected[col] = le.fit_transform(df_selected[col].astype(str))

# One-hot encode remaining low-cardinality features
df_selected = pd.get_dummies(df_selected, drop_first=True)

# Impute missing values
imputer = SimpleImputer(strategy='constant', fill_value=0)
X = imputer.fit_transform(df_selected.drop(columns=['Status_Binary']))
y = df_selected['Status_Binary']

print(f"Shape of X: {X.shape}")
print(f"Shape of y: {y.shape}")
# Out:
# Shape of X: (66009, 33)
# Shape of y: (66009,)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15492\3269962299.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected[col] = le.fit_transform(df_selected[col].astype(str))
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15492\3269962299.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected[col] = le.fit_transform(df_selected[col].astype(str))
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15492\3269962299.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected[col] = le.fit_transform(df_selected[col].astype(str))

# %%
# Evaluate Decision tree model
dt_model_moderate = DecisionTreeClassifier(
    max_depth=7,                
    min_samples_split=20,       
    min_samples_leaf=10,        
    random_state=42
)
dt_model_moderate.fit(X, y)

# Export tree rules as text
tree_rules_moderate = export_text(dt_model_moderate, feature_names=df_selected.drop(columns=['Status_Binary']).columns)
print("\nModerate Decision Tree Rules:")
print(tree_rules_moderate)

# Plot the decision tree
plt.figure(figsize=(40, 20))  
plot_tree(dt_model_moderate, 
          feature_names=df_selected.drop(columns=['Status_Binary']).columns, 
          class_names=['Renewed/Delayed Renewed', 'Not Renewed'], 
          filled=True)

plt.title('Moderate Decision Tree for Policy Non-Renewal Reasons')

plt.savefig("decision_tree_large East.png", dpi=300)  
plt.show()

with open("decision_tree_rules_test East.txt", "w") as file:
    file.write(tree_rules_moderate)
# Out:
# Moderate Decision Tree Rules:
# |--- Customer Tenure  <= 1.50
# |   |--- age <= 5060.50
# |   |   |--- Average Discount (Overall) <= 77.49
# |   |   |   |--- age <= 60.50
# |   |   |   |   |--- Average Discount (Overall) <= 57.75
# |   |   |   |   |   |--- variant <= 5906.50
# |   |   |   |   |   |   |--- Total Add on Premium (Overall) <= 11342.80
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Total Add on Premium (Overall) >  11342.80
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- variant >  5906.50
# |   |   |   |   |   |   |--- Total Add on Premium (Overall) <= 6990.25
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Total Add on Premium (Overall) >  6990.25
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- Average Discount (Overall) >  57.75
# |   |   |   |   |   |--- RTO Location  <= 448.00
# |   |   |   |   |   |   |--- Total Add on Premium (Overall) <= 5841.95
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Total Add on Premium (Overall) >  5841.95
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- RTO Location  >  448.00
# |   |   |   |   |   |   |--- Total Add on Premium (Overall) <= 498.73
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Total Add on Premium (Overall) >  498.73
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- age >  60.50
# |   |   |   |   |--- Total Add on Premium (Overall) <= 5409.75
# |   |   |   |   |   |--- Total Add on Premium (Overall) <= 124.58
# |   |   |   |   |   |   |--- Number of Declines <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Number of Declines >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Total Add on Premium (Overall) >  124.58
# |   |   |   |   |   |   |--- age <= 3340.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- age >  3340.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- Total Add on Premium (Overall) >  5409.75
# |   |   |   |   |   |--- biztype_Renewal Business <= 0.50
# |   |   |   |   |   |   |--- Total Premium Payable (Overall) <= 4951.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Total Premium Payable (Overall) >  4951.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- biztype_Renewal Business >  0.50
# |   |   |   |   |   |   |--- age <= 2810.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- age >  2810.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |--- Average Discount (Overall) >  77.49
# |   |   |   |--- biztype_Roll Over <= 0.50
# |   |   |   |   |--- variant <= 2776.50
# |   |   |   |   |   |--- Total GST (Overall) <= 1095.00
# |   |   |   |   |   |   |--- RTO Location  <= 429.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- RTO Location  >  429.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Total GST (Overall) >  1095.00
# |   |   |   |   |   |   |--- Total OD Premium (Overall) <= 6437.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Total OD Premium (Overall) >  6437.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- variant >  2776.50
# |   |   |   |   |   |--- Total Add on Premium (Overall) <= 5866.95
# |   |   |   |   |   |   |--- age <= 3466.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- age >  3466.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Total Add on Premium (Overall) >  5866.95
# |   |   |   |   |   |   |--- Total Add on Premium (Overall) <= 5990.25
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Total Add on Premium (Overall) >  5990.25
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- biztype_Roll Over >  0.50
# |   |   |   |   |--- age <= 2185.50
# |   |   |   |   |   |--- age <= 2125.50
# |   |   |   |   |   |   |--- age <= 1341.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- age >  1341.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- age >  2125.50
# |   |   |   |   |   |   |--- Total Add on Premium (Overall) <= 7477.97
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Total Add on Premium (Overall) >  7477.97
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- age >  2185.50
# |   |   |   |   |   |--- age <= 4562.50
# |   |   |   |   |   |   |--- RTO Location  <= 697.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- RTO Location  >  697.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- age >  4562.50
# |   |   |   |   |   |   |--- RTO Location  <= 1058.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- RTO Location  >  1058.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |--- age >  5060.50
# |   |   |--- variant <= 2871.00
# |   |   |   |--- variant <= 1642.00
# |   |   |   |   |--- variant <= 629.00
# |   |   |   |   |   |--- biztype_Renewal Business <= 0.50
# |   |   |   |   |   |   |--- variant <= 614.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- variant >  614.00
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- biztype_Renewal Business >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- variant >  629.00
# |   |   |   |   |   |--- Total Add on Premium (Overall) <= 8774.15
# |   |   |   |   |   |   |--- Total GST (Overall) <= 994.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Total GST (Overall) >  994.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Total Add on Premium (Overall) >  8774.15
# |   |   |   |   |   |   |--- variant <= 1472.00
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- variant >  1472.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- variant >  1642.00
# |   |   |   |   |--- biztype_Roll Over <= 0.50
# |   |   |   |   |   |--- RTO Location  <= 386.00
# |   |   |   |   |   |   |--- RTO Location  <= 168.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- RTO Location  >  168.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- RTO Location  >  386.00
# |   |   |   |   |   |   |--- Average Discount (Overall) <= 71.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Average Discount (Overall) >  71.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- biztype_Roll Over >  0.50
# |   |   |   |   |   |--- Total TP Premium (Overall) <= 8164.50
# |   |   |   |   |   |   |--- Average Discount (Overall) <= 56.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Average Discount (Overall) >  56.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Total TP Premium (Overall) >  8164.50
# |   |   |   |   |   |   |--- age <= 5223.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- age >  5223.00
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |--- variant >  2871.00
# |   |   |   |--- Total Add on Premium (Overall) <= 5727.12
# |   |   |   |   |--- biztype_Renewal Business <= 0.50
# |   |   |   |   |   |--- Average NCB % Previous Year (Overall) <= 18.75
# |   |   |   |   |   |   |--- Total OD Premium (Overall) <= 3023.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Total OD Premium (Overall) >  3023.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Average NCB % Previous Year (Overall) >  18.75
# |   |   |   |   |   |   |--- variant <= 5673.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- variant >  5673.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- biztype_Renewal Business >  0.50
# |   |   |   |   |   |--- Average Discount (Overall) <= 31.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Average Discount (Overall) >  31.50
# |   |   |   |   |   |   |--- RTO Location  <= 429.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- RTO Location  >  429.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- Total Add on Premium (Overall) >  5727.12
# |   |   |   |   |--- Average Discount (Overall) <= 73.12
# |   |   |   |   |   |--- Average Discount (Overall) <= 58.42
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Average Discount (Overall) >  58.42
# |   |   |   |   |   |   |--- Total Add on Premium (Overall) <= 9671.19
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Total Add on Premium (Overall) >  9671.19
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- Average Discount (Overall) >  73.12
# |   |   |   |   |   |--- age <= 5855.50
# |   |   |   |   |   |   |--- Total Premium Payable (Overall) <= 8197.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Total Premium Payable (Overall) >  8197.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- age >  5855.50
# |   |   |   |   |   |   |--- class: 0
# |--- Customer Tenure  >  1.50
# |   |--- New Customer_Yes <= 0.50
# |   |   |--- Number of Vehicles <= 1.50
# |   |   |   |--- Customer Tenure  <= 2.50
# |   |   |   |   |--- biztype_Renewal Business <= 0.50
# |   |   |   |   |   |--- Total Add on Premium (Overall) <= 5496.19
# |   |   |   |   |   |   |--- age <= 5213.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- age >  5213.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Total Add on Premium (Overall) >  5496.19
# |   |   |   |   |   |   |--- Total GST (Overall) <= 1205.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Total GST (Overall) >  1205.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- biztype_Renewal Business >  0.50
# |   |   |   |   |   |--- Total OD Premium (Overall) <= 258.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- Total OD Premium (Overall) >  258.50
# |   |   |   |   |   |   |--- Total Premium Payable (Overall) <= 10782.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Total Premium Payable (Overall) >  10782.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- Customer Tenure  >  2.50
# |   |   |   |   |--- Total OD Premium (Overall) <= 6433.50
# |   |   |   |   |   |--- Total Add on Premium (Overall) <= 5067.80
# |   |   |   |   |   |   |--- Total OD Premium (Overall) <= 1244.00
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Total OD Premium (Overall) >  1244.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Total Add on Premium (Overall) >  5067.80
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- Total OD Premium (Overall) >  6433.50
# |   |   |   |   |   |--- Number of Claims <= 0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Number of Claims >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |--- Number of Vehicles >  1.50
# |   |   |   |--- Total TP Premium (Overall) <= 4378.00
# |   |   |   |   |--- Total OD Premium (Overall) <= 9424.50
# |   |   |   |   |   |--- Average NCB % Previous Year (Overall) <= 27.50
# |   |   |   |   |   |   |--- variant <= 3063.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- variant >  3063.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Average NCB % Previous Year (Overall) >  27.50
# |   |   |   |   |   |   |--- Average Discount (Overall) <= 52.88
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Average Discount (Overall) >  52.88
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- Total OD Premium (Overall) >  9424.50
# |   |   |   |   |   |--- Average Discount (Overall) <= 74.94
# |   |   |   |   |   |   |--- Total Add on Premium (Overall) <= 18043.56
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Total Add on Premium (Overall) >  18043.56
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Average Discount (Overall) >  74.94
# |   |   |   |   |   |   |--- RTO Location  <= 884.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- RTO Location  >  884.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- Total TP Premium (Overall) >  4378.00
# |   |   |   |   |--- Average Discount (Overall) <= 75.72
# |   |   |   |   |   |--- Number of Vehicles <= 2.50
# |   |   |   |   |   |   |--- Number of Declines <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Number of Declines >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Number of Vehicles >  2.50
# |   |   |   |   |   |   |--- Total Premium Payable (Overall) <= 32338.00
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Total Premium Payable (Overall) >  32338.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- Average Discount (Overall) >  75.72
# |   |   |   |   |   |--- Total Premium Payable (Overall) <= 10156.50
# |   |   |   |   |   |   |--- Average NCB % Previous Year (Overall) <= 43.75
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Average NCB % Previous Year (Overall) >  43.75
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Total Premium Payable (Overall) >  10156.50
# |   |   |   |   |   |   |--- Average NCB % Previous Year (Overall) <= 31.67
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Average NCB % Previous Year (Overall) >  31.67
# |   |   |   |   |   |   |   |--- class: 0
# |   |--- New Customer_Yes >  0.50
# |   |   |--- Customer Tenure  <= 2.50
# |   |   |   |--- Number of Policies <= 1.50
# |   |   |   |   |--- Number of Declines <= 0.50
# |   |   |   |   |   |--- Total OD Premium (Overall) <= 10553.50
# |   |   |   |   |   |   |--- biztype_Renewal Business <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- biztype_Renewal Business >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- Total OD Premium (Overall) >  10553.50
# |   |   |   |   |   |   |--- age <= 152.00
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- age >  152.00
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- Number of Declines >  0.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- Number of Policies >  1.50
# |   |   |   |   |--- Average NCB % Previous Year (Overall) <= 9.38
# |   |   |   |   |   |--- age <= 3343.50
# |   |   |   |   |   |   |--- Total Add on Premium (Overall) <= 12163.98
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Total Add on Premium (Overall) >  12163.98
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- age >  3343.50
# |   |   |   |   |   |   |--- Number of Declines <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Number of Declines >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- Average NCB % Previous Year (Overall) >  9.38
# |   |   |   |   |   |--- biztype_Renewal Business <= 0.50
# |   |   |   |   |   |   |--- Average Discount (Overall) <= 74.35
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Average Discount (Overall) >  74.35
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- biztype_Renewal Business >  0.50
# |   |   |   |   |   |   |--- age <= 3067.00
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- age >  3067.00
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |--- Customer Tenure  >  2.50
# |   |   |   |--- Average NCB % Previous Year (Overall) <= 1.25
# |   |   |   |   |--- age <= 2785.00
# |   |   |   |   |   |--- Total OD Premium (Overall) <= 9386.00
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- Total OD Premium (Overall) >  9386.00
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- age >  2785.00
# |   |   |   |   |   |--- Customer Tenure  <= 3.50
# |   |   |   |   |   |   |--- age <= 2936.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- age >  2936.00
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- Customer Tenure  >  3.50
# |   |   |   |   |   |   |--- Total Premium Payable (Overall) <= 6603.00
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Total Premium Payable (Overall) >  6603.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- Average NCB % Previous Year (Overall) >  1.25
# |   |   |   |   |--- Average NCB % Previous Year (Overall) <= 43.75
# |   |   |   |   |   |--- RTO Location  <= 862.50
# |   |   |   |   |   |   |--- Total OD Premium (Overall) <= 2700.00
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Total OD Premium (Overall) >  2700.00
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- RTO Location  >  862.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- Average NCB % Previous Year (Overall) >  43.75
# |   |   |   |   |   |--- biztype_Renewal Business <= 0.50
# |   |   |   |   |   |   |--- Total Premium Payable (Overall) <= 7306.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Total Premium Payable (Overall) >  7306.00
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- biztype_Renewal Business >  0.50
# |   |   |   |   |   |   |--- class: 0

# %%
from sklearn.metrics import accuracy_score, log_loss, roc_auc_score, classification_report, confusion_matrix, roc_curve
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier

# Simplified Random Forest model
model = RandomForestClassifier(
    n_estimators=200,          # More trees for stability
    max_depth=12,              # Slightly increased depth
    min_samples_split=15,      # Increase to reduce overfitting
    min_samples_leaf=10,        # Increase to reduce overfitting
    class_weight='balanced',   # Handle class imbalance
    random_state=42
)

model.fit(X, y)

# Evaluate the Feature Importance
feature_importances = pd.Series(model.feature_importances_, index=df_selected.drop(columns=['Status_Binary']).columns)

print("Feature Importance (all features):")
print(feature_importances)

# Plot the Feature importance graph
plt.figure(figsize=(20, 12))
sns.barplot(x=feature_importances.sort_values(ascending=False), y=feature_importances.sort_values(ascending=False).index, palette="coolwarm")
plt.title('Feature Importance')
plt.xlabel('Importance')
plt.ylabel('Features')
plt.show()

feature_importances_df = pd.DataFrame({'Feature': feature_importances.index, 'Importance': feature_importances.values})
feature_importances_df.to_csv('feature_importances East.csv', index=False)
# Out:
# Feature Importance (all features):
# variant                                              3.699870e-02
# RTO Location                                         1.611656e-02
# age                                                  4.792031e-02
# Number of Vehicles                                   1.602138e-02
# Number of Policies                                   1.571278e-02
# Total Premium Payable (Overall)                      2.370292e-02
# Total OD Premium (Overall)                           2.985381e-02
# Total TP Premium (Overall)                           2.259049e-02
# Total Add on Premium (Overall)                       3.154318e-02
# Average Discount (Overall)                           3.626426e-02
# Average NCB % Previous Year (Overall)                3.391833e-02
# Total GST (Overall)                                  2.411807e-02
# Number of Claims                                     2.829784e-03
# Number of Declines                                   1.351496e-02
# Customer Tenure                                      5.205146e-01
# Product name  2_Package, SOD                         5.284000e-04
# Product name  2_SOD                                  9.495729e-03
# Product name  2_SOD, Package                         1.671345e-03
# biztype_New Business, Renewal Business               1.071693e-04
# biztype_New Business, Renewal Business, Roll Over    0.000000e+00
# biztype_New Business, Roll Over                      1.518580e-04
# biztype_New Business, Roll Over, Renewal Business    1.674843e-06
# biztype_Renewal Business                             2.735553e-02
# biztype_Renewal Business, New Business               3.824967e-05
# biztype_Renewal Business, New Business, Roll Over    2.602594e-06
# biztype_Renewal Business, Roll Over                  3.032636e-04
# biztype_Renewal Business, Roll Over, New Business    0.000000e+00
# biztype_Roll Over                                    1.157006e-02
# biztype_Roll Over, New Business                      4.209633e-05
# biztype_Roll Over, New Business, Renewal Business    1.435885e-07
# biztype_Roll Over, Renewal Business                  3.452051e-05
# biztype_Roll Over, Renewal Business, New Business    0.000000e+00
# New Customer_Yes                                     7.707726e-02
# dtype: float64
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15492\3418711876.py:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=feature_importances.sort_values(ascending=False), y=feature_importances.sort_values(ascending=False).index, palette="coolwarm")
